# %%
from google.cloud import bigquery
import pandas as pd
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "C:/Users/User/Desktop/blockchain_research/eth-dataset-372206-0985b468a014.json"
client = bigquery.Client()

# %%
query4 = """ 
SELECT 
  token_address,
  from_address,
  to_address,
  value,
  transaction_hash,
  block_timestamp,
  block_number,
  block_hash

FROM
  bigquery-public-data.crypto_ethereum.token_transfers as token_transfers
WHERE
  # EXTRACT(YEAR FROM block_timestamp) = 2015
  # AND EXTRACT(YEAR FROM block_timestamp) <= 2018
  block_timestamp > timestamp_sub(current_timestamp, INTERVAL 1 DAY)
ORDER BY block_timestamp
"""

# %%
df2 = client.query(query4).to_dataframe()
df2.head()
# Out:
#                                 token_address  \
# 0  0x5f076e995290f3f9aea85fdd06d8fae118f2b75c
# 1  0x51cb253744189f11241becb29bedd3f1b5384fdb
# 2  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3  0x0000000000a39bb272e79075ade125fd351887ac
# 4  0x5f076e995290f3f9aea85fdd06d8fae118f2b75c
#
#                                  from_address  \
# 0  0x0000000000000000000000000000000000000000
# 1  0xb8a4fe9897485496ec866938c71b74e4fe7d2b5e
# 2  0x1111111254eeb25477b68fb85ed929f73a960582
# 3  0xdd19bc73f142a44c966a12313fdbb71e5a838331
# 4  0x0000000000000000000000000000000000000000
#
#                                    to_address                    value  \
# 0  0xca4319c1738d056b0671c893529654ff8167e762                     1355
# 1  0x74de5d4fcbf63e00296fd95d33236b9794016631  10000000000000000000000
# 2  0x5cead0ca2c1b7ac4b98f6ec4d2b27c219237abff               3267218440
# 3  0x0000000000000000000000000000000000000000       440000000000000000
# 4  0x8efd6e2bb4338df1df7be65bf9ae87d7c990e83c                     1343
#
#                                     transaction_hash  \
# 0  0x7b041e5da049aaa60b76f90bc8da34ed861fa7ef0a03...
# 1  0x9a8a3ce962215c1fafdaa71e370fc6887620e50749d7...
# 2  0x51843431b7ed34c3904b29a3cecaeca823a14ea76f92...
# 3  0x10bd1ef0f93ea51d6e9901412ea6a7b120399679f71c...
# 4  0x2b55e656f19670d23c2367fa6e0a6c5ce39a3dcaa7cb...
#
#             block_timestamp  block_number  \
# 0 2023-02-21 16:43:23+00:00      16678141
# 1 2023-02-21 16:43:23+00:00      16678141
# 2 2023-02-21 16:43:23+00:00      16678141
# 3 2023-02-21 16:43:23+00:00      16678141
# 4 2023-02-21 16:43:23+00:00      16678141
#
#                                           block_hash
# 0  0x52ca410e0c5837e25d9a43804b815facbb2774b37c21...
# 1  0x52ca410e0c5837e25d9a43804b815facbb2774b37c21...
# 2  0x52ca410e0c5837e25d9a43804b815facbb2774b37c21...
# 3  0x52ca410e0c5837e25d9a43804b815facbb2774b37c21...
# 4  0x52ca410e0c5837e25d9a43804b815facbb2774b37c21...
