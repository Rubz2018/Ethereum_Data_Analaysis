# %%
from google.cloud import bigquery
import pandas as pd
import os
from google.cloud import bigquery
import pandas_gbq
from tqdm import tqdm
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/Users/dr.rubaiyatislam/Documents/big_query/keyfile.json"
client = bigquery.Client()

# %%
# %pip install pandas_gbq

# %%
query2 = """ 
SELECT 
  transactions.hash as hsh,
  nonce,
  transaction_index,
  from_address,
  to_address,
  value,
  gas,
  gas_price,
  input,
  receipt_cumulative_gas_used,
  receipt_gas_used,
  receipt_contract_address,
  receipt_root,
  receipt_status,
  block_timestamp,
  block_number,
  block_hash,
  
FROM
  bigquery-public-data.crypto_ethereum.transactions as transactions
WHERE
  (from_address = '0xc0a47dFe034B400B47bDaD5FecDa2621de6c4d95' OR to_address = '0xc0a47dFe034B400B47bDaD5FecDa2621de6c4d95')
  AND DATE(block_timestamp) >= '2022-08-18' AND DATE(block_timestamp) <= '2023-08-18'
  # EXTRACT(YEAR FROM block_timestamp) >= 2017
  # AND EXTRACT(YEAR FROM block_timestamp) < 2018
  #block_timestamp > timestamp_sub(current_timestamp, INTERVAL 1 DAY)
ORDER BY block_timestamp
"""

# %%
# query3 = """ 
# SELECT 
#   transactions.hash as hsh,
#   nonce,
#   transaction_index,
#   from_address,
#   to_address,
#   value,
#   gas,
#   gas_price,
#   input,
#   receipt_cumulative_gas_used,
#   receipt_gas_used,
#   receipt_contract_address,
#   receipt_root,
#   receipt_status,
#   block_timestamp,
#   block_number,
#   block_hash,
  
# FROM
#   bigquery-public-data.crypto_ethereum.transactions as transactions
# WHERE
# #   EXTRACT(YEAR FROM block_timestamp) = 2015
# #   AND EXTRACT(YEAR FROM block_timestamp) <= 2023
#    block_timestamp > timestamp_sub(current_timestamp, INTERVAL 1 DAY)
# ORDER BY block_timestamp
# """

# %%
# df3= client.query(query3).to_dataframe()
# df3.head()

# %%
# df3.tail()

# %%
# print(len(df3))

# %%
df2 = pandas_gbq.read_gbq(
    query2, project_id=client.project, progress_bar_type='tqdm')

df2.head()
# Out:
# Downloading: |          |
# Empty DataFrame
# Columns: [hsh, nonce, transaction_index, from_address, to_address, value, gas, gas_price, input, receipt_cumulative_gas_used, receipt_gas_used, receipt_contract_address, receipt_root, receipt_status, block_timestamp, block_number, block_hash]
# Index: []

# %%
df.tail()

# %%
df.head()

# %%
df.to_csv("/Users/dr.rubaiyatislam/Documents/big_query/transactions_2017.txt",sep='\t')

# %%
export_df = pd.read_csv('/Users/dr.rubaiyatislam/Documents/big_query/transactions_2017.txt',sep='\t')
export_df.head(3)

# %%
export_df.tail(3)

# %%
print(len(export_df))

# %%
export_df.columns
