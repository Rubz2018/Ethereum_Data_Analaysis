# %% [markdown]
# # Big Query to download Ethereum data
# -  The following code has been taken from the kaggle notebook as reference.
# - A service account needs to be created.
# - bigquery and db-mbs library needs to be installed.

# %%
# %pip install db-dtypes
# %pip install google-cloud-bigquery

# %%
from google.cloud import bigquery
import pandas as pd
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "C:/Users/User/Desktop/blockchain_research/eth-dataset-372206-0985b468a014.json"
client = bigquery.Client()

# %%
# query = """
# SELECT 
#   SUM(value/POWER(10,18)) AS sum_tx_ether,
#   AVG(gas_price*(receipt_gas_used/POWER(10,18))) AS avg_tx_gas_cost,
#   DATE(timestamp) AS tx_date
# FROM
#   `bigquery-public-data.crypto_ethereum.transactions` AS transactions,
#   `bigquery-public-data.crypto_ethereum.blocks` AS blocks
# WHERE TRUE
#   AND transactions.block_number = blocks.number
#   AND receipt_status = 1
#   AND value > 0
# GROUP BY tx_date
# HAVING tx_date >= '2015-01-01' AND tx_date <= '2023-12-31'
# ORDER BY tx_date
# """
# query_job = client.query(query)

# iterator = query_job.result(timeout=90)
# rows = list(query_job)

# # Transform the rows into a nice pandas dataframe
# df = pd.DataFrame(data=[list(x.values()) for x in rows], columns=list(rows[0].keys()))

# # Look at the first 10
# df.tail(3)

# %% [markdown]
# # Block table and the attributes from 2015 to 2018
# - The following query explores all the attributes of the block

# %% [markdown]
# - The following query works if we omit 'hash' attribute.
# - We need to fix the hash attribute error issue.

# %% [markdown]
# Test Query

# %%
# This works on my pc and on kaggle
query2 = """ 
SELECT 
  timestamp,
  number AS block_number,
  blocks.hash AS hsh,
  parent_hash
  nonce,
  miner,
  difficulty,
  size,
  gas_limit,
  gas_used,
  transaction_count
  base_fee_per_gas
  
FROM
  bigquery-public-data.crypto_ethereum.blocks AS blocks
WHERE
  timestamp > timestamp_sub(current_timestamp, INTERVAL 1 DAY)
ORDER BY timestamp
"""

# %%
# Execute the query and convert the results to a Pandas DataFrame
df2 = client.query(query2).to_dataframe()
df2.head()
# Out:
#                   timestamp  block_number  \
# 0 2023-02-21 16:31:35+00:00      16678082
# 1 2023-02-21 16:31:47+00:00      16678083
# 2 2023-02-21 16:31:59+00:00      16678084
# 3 2023-02-21 16:32:11+00:00      16678085
# 4 2023-02-21 16:32:23+00:00      16678086
#
#                                                  hsh  \
# 0  0xc9c04b8212286a83f3436f90b181ce4314057dfa3b0a...
# 1  0x641db0e562fc260aa6e2fc875700bc2602fe73f76675...
# 2  0x6806ae71b68c03178e8ab875afb981fb44f4fe6548dd...
# 3  0x817b6068585bb7f86f62eb926bf45833803d890e4129...
# 4  0x470977f8251ba9b074b64fa7c388e06e5fc93d8c0ea9...
#
#                                                nonce  \
# 0  0x3e1270844e876c20ba2bfb3ffbbec4c4b83ed070c759...
# 1  0xc9c04b8212286a83f3436f90b181ce4314057dfa3b0a...
# 2  0x641db0e562fc260aa6e2fc875700bc2602fe73f76675...
# 3  0x6806ae71b68c03178e8ab875afb981fb44f4fe6548dd...
# 4  0x817b6068585bb7f86f62eb926bf45833803d890e4129...
#
#                                         miner difficulty    size  gas_limit  \
# 0  0x690b9a9e9aa1c9db991c7721a92d351db4fac990       0E-9   84648   30000000
# 1  0x6d2e03b7effeae98bd302a9f836d0d6ab0002766       0E-9   77449   30000000
# 2  0xdafea492d9c6733ae3d56b7ed1adb60692c98bc5       0E-9   48480   30000000
# 3  0xbaf6dc2e647aeb6f510f9e318856a1bcd66c5e19       0E-9  199520   30000000
# 4  0x95222290dd7278aa3ddd389cc1e1d165cc4bafe5       0E-9   46682   30000000
#
#    gas_used  base_fee_per_gas
# 0  14840115               182
# 1  14936594               148
# 2  10864974               143
# 3  17767254               168
# 4  11130563               126

# %%
# Exporting the dataframe to a text file:
df2.to_csv("/Users/dr.rubaiyatislam/Documents/big_query/block.txt",sep='\t')

# %%
export_df = pd.read_csv('/Users/dr.rubaiyatislam/Documents/big_query/block.txt',sep='\t')
export_df.head(3)

# %%
export_df.tail(3)

# %%
print(len(export_df))

# %%
export_df.columns
