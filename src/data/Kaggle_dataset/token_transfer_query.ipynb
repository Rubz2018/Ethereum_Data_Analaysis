# %%
from google.cloud import bigquery
import pandas as pd
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/Users/dr.rubaiyatislam/Documents/big_query/keyfile.json"
client = bigquery.Client()

# %%
query4 = """ 
SELECT 
  token_address,
  from_address,
  to_address,
  value,
  transaction_hash,
  block_timestamp,
  block_number,
  block_hash

FROM
  bigquery-public-data.crypto_ethereum.token_transfers as token_transfers
WHERE
  # EXTRACT(YEAR FROM block_timestamp) = 2015
  # AND EXTRACT(YEAR FROM block_timestamp) <= 2018
  block_timestamp > timestamp_sub(current_timestamp, INTERVAL 1 DAY)
ORDER BY block_timestamp
"""

# %%
df2 = client.query(query4).to_dataframe()
df2.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-5e3ab7f03feb> in <module>
# ----> 1 df2 = client.query(query4).to_dataframe()
#       2 df2.head()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object)
#    1686         """
#    1687         query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
# -> 1688         return query_result.to_dataframe(
#    1689             bqstorage_client=bqstorage_client,
#    1690             dtypes=dtypes,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/table.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, geography_as_object)
#    2005             bqstorage_client = None
#    2006
# -> 2007         record_batch = self.to_arrow(
#    2008             progress_bar_type=progress_bar_type,
#    2009             bqstorage_client=bqstorage_client,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/table.py in to_arrow(self, progress_bar_type, bqstorage_client, create_bqstorage_client)
#    1808
#    1809             record_batches = []
# -> 1810             for record_batch in self.to_arrow_iterable(
#    1811                 bqstorage_client=bqstorage_client
#    1812             ):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/table.py in _to_page_iterable(self, bqstorage_download, tabledata_list_download, bqstorage_client)
#    1671             else tabledata_list_download()
#    1672         )
# -> 1673         yield from result_pages
#    1674
#    1675     def to_arrow_iterable(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/google/cloud/bigquery/_pandas_helpers.py in _download_table_bqstorage(project_id, table, bqstorage_client, preserve_order, selected_fields, page_to_item, max_queue_size)
#     919
#     920                 try:
# --> 921                     frame = worker_queue.get(timeout=_PROGRESS_INTERVAL)
#     922                     yield frame
#     923                 except queue.Empty:  # pragma: NO COVER
#
# ~/opt/anaconda3/lib/python3.9/queue.py in get(self, block, timeout)
#     178                     if remaining <= 0.0:
#     179                         raise Empty
# --> 180                     self.not_empty.wait(remaining)
#     181             item = self._get()
#     182             self.not_full.notify()
#
# ~/opt/anaconda3/lib/python3.9/threading.py in wait(self, timeout)
#     314             else:
#     315                 if timeout > 0:
# --> 316                     gotit = waiter.acquire(True, timeout)
#     317                 else:
#     318                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
