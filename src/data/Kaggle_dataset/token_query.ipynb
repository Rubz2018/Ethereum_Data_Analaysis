# %%
query5 = """ 
SELECT 
  address,
  token_name,
  decimal,
  total_supply,
  block_timestamp,
  block_number,
  block_hash

FROM
  `bigquery-public-data.crypto_ethereum.token`
WHERE
  EXTRACT(YEAR FROM block_timestamp) = 2015
  # AND EXTRACT(YEAR FROM block_timestamp) <= 2018
ORDER BY block_timestamp
"""
