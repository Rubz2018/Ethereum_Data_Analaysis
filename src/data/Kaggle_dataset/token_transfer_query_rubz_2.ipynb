# %%
from google.cloud import bigquery
import pandas as pd
import os
from google.cloud import bigquery
import pandas_gbq
from tqdm import tqdm
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/Users/dr.rubaiyatislam/Documents/big_query/keyfile.json"
client = bigquery.Client()

# %%
query3 = """ 
SELECT 
  token_address,
  from_address,
  to_address,
  value,
  transaction_hash,
  DATE(block_timestamp) AS block_timestamp,
  block_number,
  block_hash

FROM
  bigquery-public-data.crypto_ethereum.token_transfers as token_transfers
WHERE
   DATE(block_timestamp) >= '2023-08-18' AND DATE(block_timestamp) <= '2023-08-18'
   #block_timestamp > timestamp_sub(current_timestamp, INTERVAL 1 DAY)
ORDER BY block_timestamp
"""

# %%
df3 = pandas_gbq.read_gbq(
    query3, project_id=client.project, progress_bar_type='tqdm')

df3.head()
# Out:
# Downloading: 100%|██████████|
#                                 token_address  \
# 0  0xb478c6245e3d85d6ec3486b62ea872128d562541
# 1  0x6cca981e8e1e318a696feb455d298fc65227ed8d
# 2  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3  0x204c1f431a23afaef6294cd128eea822eb9419ba
# 4  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
#                                  from_address  \
# 0  0x57bbcb3da0b6983bde4bd8b9c605ebc65fb3b06f
# 1  0x0ae879fb0f2e630ed3d423eb09e925c63495cfe6
# 2  0x3fc91a3afd70395cd496c647d5a6cc9d4b2b7fad
# 3  0x44f3791ad797ddc9144008bf6396124fbcc491b9
# 4  0x0821e3cb9d5c653622b6c7b9dceddf3581880d34
#
#                                    to_address                   value  \
# 0  0xb478c6245e3d85d6ec3486b62ea872128d562541    13872653565583204250
# 1  0xbf6084876b8a94bea89f123a3621980ff88ed395  1625720000000000000000
# 2  0x98bb850ff2e55a886a281e37324b72ce4d51e02d       17474237985334200
# 3  0x7c66c8434a91bd5e50995ae4a523513514fcaff8            565191000000
# ...

# %%
# Exporting the dataframe to a text file:
df3.to_csv("/Users/dr.rubaiyatislam/Documents/big_query/token_transfer_Pos_2022_10_26_11_05.txt",sep=',')

# %%
export_df3 = pd.read_csv('/Users/dr.rubaiyatislam/Documents/big_query/token_transfer_Pos_2022_10_26_11_05.txt',sep=',')
export_df3.head(3)
# Out:
#    Unnamed: 0                               token_address  \
# 0           0  0xb478c6245e3d85d6ec3486b62ea872128d562541
# 1           1  0x6cca981e8e1e318a696feb455d298fc65227ed8d
# 2           2  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
#                                  from_address  \
# 0  0x57bbcb3da0b6983bde4bd8b9c605ebc65fb3b06f
# 1  0x0ae879fb0f2e630ed3d423eb09e925c63495cfe6
# 2  0x3fc91a3afd70395cd496c647d5a6cc9d4b2b7fad
#
#                                    to_address                   value  \
# 0  0xb478c6245e3d85d6ec3486b62ea872128d562541    13872653565583204250
# 1  0xbf6084876b8a94bea89f123a3621980ff88ed395  1625720000000000000000
# 2  0x98bb850ff2e55a886a281e37324b72ce4d51e02d       17474237985334200
#
#                                     transaction_hash block_timestamp  \
# 0  0xc0a76178c6a1476e308a16852ea30476e19898e71688...      2023-08-18
# 1  0x6bfa5da66ffce544193da9e3ebba0b87bb943aeeae6b...      2023-08-18
# ...

# %%
export_df3.tail(3)
# Out:
#          Unnamed: 0                               token_address  \
# 1241992     1241992  0x8290333cef9e6d528dd5618fb97a76f268f3edd4
# 1241993     1241993  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1241994     1241994  0xbb9fd9fa4863c03c574007ff3370787b9ce65ff6
#
#                                        from_address  \
# 1241992  0xa9d1e08c7793af67e9d92fe308d5697fb81d3e43
# 1241993  0xc4bcaed8570fa0d8ab5a0e6a5cf3b7871f87af82
# 1241994  0x1d9a941da508d9c603128f7776e19910c4fc8d1b
#
#                                          to_address                   value  \
# 1241992  0x0da2e115a73ffc264799f396c4a2e1c59ccfa527   883396789820000000000
# 1241993  0xdce92f40cadde2c4e3ea78b8892c540e6bfe2f81                93569855
# 1241994  0x55174f68e7fa87b9309920b413233789dc4a9d1d  2425382171034789681125
#
#                                           transaction_hash block_timestamp  \
# 1241992  0x13c7d05e4bb4665479a4acf3dd75b1e8b0f6f0ed7216...      2023-08-18
# ...

# %%
print(len(export_df3))
# Out:
# 1241995

# %%
export_df3.columns
# Out:
# Index(['Unnamed: 0', 'token_address', 'from_address', 'to_address', 'value',
#        'transaction_hash', 'block_timestamp', 'block_number', 'block_hash'],
#       dtype='object')

# %%
query4 = """ 
SELECT 
  address,
  is_erc20,
  is_erc721,
  DATE(block_timestamp) AS block_timestamp,
  block_number,

FROM
  bigquery-public-data.crypto_ethereum.contracts as contracts
WHERE
  address = '0xc0a47dFe034B400B47bDaD5FecDa2621de6c4d95'
  AND DATE(block_timestamp) >= '2017-08-18' AND DATE(block_timestamp) <= '2023-08-18'
  #block_timestamp > timestamp_sub(current_timestamp, INTERVAL 1 DAY)
ORDER BY block_timestamp
"""

# %%
df4 = pandas_gbq.read_gbq(
    query4, project_id=client.project, progress_bar_type='tqdm')

df4.head()
# Out:
# Downloading: |          |
# Empty DataFrame
# Columns: [address, is_erc20, is_erc721, block_timestamp, block_number]
# Index: []
