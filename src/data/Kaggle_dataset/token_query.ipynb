# %%
from google.cloud import bigquery
import pandas as pd
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "C:/Users/User/Desktop/blockchain_research/eth-dataset-372206-0985b468a014.json"
client = bigquery.Client()

# %%
query5 = """ 
SELECT 
  address,
  name,
  decimals,
  total_supply,
  block_timestamp,
  block_number,
  block_hash

FROM
  bigquery-public-data.crypto_ethereum.tokens as tokens
WHERE
  # EXTRACT(YEAR FROM block_timestamp) = 2015
  # AND EXTRACT(YEAR FROM block_timestamp) <= 2018
  block_timestamp > timestamp_sub(current_timestamp, INTERVAL 1 DAY)
ORDER BY block_timestamp
"""

# %%
df2 = client.query(query5).to_dataframe()
df2.head()
# Out:
#                                       address                 name decimals  \
# 0  0x376b3233a92e2ad6f3c61453a4a966920b73ab6f                          None
# 1  0xfb27de6ed15e20d84d9a6ec92e784e40587de768                          None
# 2  0x6d3e52161c075e10cdc95b3b0fc9793a547167a2        Extraordinals     None
# 3  0xac7bb5635e88c9a26b56a54b99320c2ce67416ac  PRESTES ERC20 Token       18
# 4  0x6df259d5e5ee094fa283f6b69b39f0b8bf3f45b8             BTCPENIS        6
#
#                 total_supply           block_timestamp  block_number  \
# 0                          0 2023-02-21 18:33:59+00:00      16678685
# 1                          0 2023-02-21 19:10:11+00:00      16678863
# 2                        100 2023-02-21 21:10:23+00:00      16679458
# 3  1000000000000000000000000 2023-02-22 01:20:11+00:00      16680691
# 4             21000000000000 2023-02-22 01:29:59+00:00      16680740
#
#                                           block_hash
# ...
