# %%
from google.cloud import bigquery
import pandas as pd
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "C:/Users/User/Desktop/blockchain_research/eth-dataset-372206-0985b468a014.json"
client = bigquery.Client()

# %%
query3 = """ 
SELECT 
  address,
  is_erc20,
  is_erc721,
  block_timestamp,
  block_number,

FROM
  bigquery-public-data.crypto_ethereum.contracts as contracts
WHERE
  # EXTRACT(YEAR FROM block_timestamp) = 2015
  # AND EXTRACT(YEAR FROM block_timestamp) <= 2018
    block_timestamp > timestamp_sub(current_timestamp, INTERVAL 1 DAY)
ORDER BY block_timestamp
"""

# %%
df2 = client.query(query3).to_dataframe()
df2.head()
# Out:
#                                       address  is_erc20  is_erc721  \
# 0  0xdccea9bb66740c457042795da26eb165161a8b78     False      False
# 1  0x1092a57c3b4d029555020215455097dec6ba7fe5     False      False
# 2  0xfe34d371bd286be18ce819281705e5f30ebddad2     False      False
# 3  0xa4850e2481698ce032bc6e32ced280c2c59d1715     False      False
# 4  0x58ba83c0e2c8ecc0a6790c3d8e66f942db28a4d1     False      False
#
#             block_timestamp  block_number
# 0 2023-02-21 16:59:35+00:00      16678222
# 1 2023-02-21 16:59:35+00:00      16678222
# 2 2023-02-21 16:59:59+00:00      16678224
# 3 2023-02-21 17:00:23+00:00      16678226
# 4 2023-02-21 17:00:47+00:00      16678228
